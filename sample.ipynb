# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt") # Или вашу модель
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ultralytics import YOLO
#       2 model = YOLO("yolov8n.pt") # Или вашу модель
#
# File E:\YOLO_OBUCHENIE_2\.venv\Lib\site-packages\ultralytics\__init__.py:13
#      10 if not os.environ.get("OMP_NUM_THREADS"):
#      11     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 13 from ultralytics.utils import ASSETS, SETTINGS
#      14 from ultralytics.utils.checks import check_yolo as checks
#      15 from ultralytics.utils.downloads import download
#
# File E:\YOLO_OBUCHENIE_2\.venv\Lib\site-packages\ultralytics\utils\__init__.py:660
#     656         LOGGER.info(f"Printing '{colorstr('bold', 'black', yaml_file)}'\n\n{dump}")
#     659 # Default configuration
# --> 660 DEFAULT_CFG_DICT = YAML.load(DEFAULT_CFG_PATH)
#     661 DEFAULT_CFG_KEYS = DEFAULT_CFG_DICT.keys()
#     662 DEFAULT_CFG = IterableSimpleNamespace(**DEFAULT_CFG_DICT)
#
# File E:\YOLO_OBUCHENIE_2\.venv\Lib\site-packages\ultralytics\utils\__init__.py:617, in YAML.load(cls, file, append_filename)
#     614 assert str(file).endswith((".yaml", ".yml")), f"Not a YAML file: {file}"
#     616 # Read file content
# --> 617 with open(file, errors="ignore", encoding="utf-8") as f:
#     618     s = f.read()
#     620 # Try loading YAML with fallback for problematic characters
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\YOLO_OBUCHENIE_2\\.venv\\Lib\\site-packages\\ultralytics\\cfg\\default.yaml'
